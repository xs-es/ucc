# %%
from qbraid.transpiler import ConversionGraph

graph = ConversionGraph()

len(graph.nodes()) # 10
len(graph.edges()) # 25

graph.plot(legend=True)

# %%
supported_circuit_formats = ConversionGraph().nodes()
supported_circuit_formats
# Out:
# ['cirq',
#  'braket',
#  'pyquil',
#  'qasm2',
#  'qiskit',
#  'qasm3',
#  'pennylane',
#  'pytket',
#  'openqasm3']

# %%
from ucc import supported_circuit_formats

supported_circuit_formats
# Out:
# ['cirq',
#  'braket',
#  'pyquil',
#  'qasm2',
#  'qiskit',
#  'qasm3',
#  'pennylane',
#  'pytket',
#  'openqasm3']
